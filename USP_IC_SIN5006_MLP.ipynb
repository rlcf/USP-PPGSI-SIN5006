# %% [markdown]
# <a href="https://colab.research.google.com/github/rlcf/USP-PPGSI-SIN5006/blob/main/USP_IC_SIN5006_MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Pipeline - Modelo MLP - Projeto USP-IC-SIN5006
# Este notebook executa o modelo MLP sobre todas as bases localizadas na pasta `datasets` do Google Drive.
# Os resultados (previsões, gráficos e métricas) serão salvos automaticamente na pasta `outputs`.
# ---

# %%
# 🔧 Instalação de pacotes necessários
# !pip install tensorflow scikit-learn pandas matplotlib seaborn plotly --quiet

# 🔗 Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 🗂️ Definir os caminhos das pastas
base_path = '/content/drive/MyDrive/USP-IC-SIN5006/'
datasets_path = base_path + 'datasets/'
outputs_path = base_path + 'outputs/'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, GRU
import os
import glob

datasets = glob.glob(datasets_path + '*.csv')
print(f'🗂️ Bases encontradas: {datasets}')

def create_sequences(data, look_back=30):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

def build_model(input_shape):
    model = Sequential()
    if 'MLP' == 'LSTM':
        model.add(LSTM(50, activation='tanh', input_shape=input_shape))
    elif 'MLP' == 'GRU':
        model.add(GRU(50, activation='tanh', input_shape=input_shape))
    elif 'MLP' == 'MLP':
        model.add(Dense(64, activation='relu', input_shape=(input_shape[0],)))
        model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

def evaluate_model(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = mean_squared_error(y_true, y_pred) ** 0.5
    r2 = r2_score(y_true, y_pred)
    return {'MAE': mae, 'RMSE': rmse, 'R2': r2}

results = []
look_back = 30

for dataset_path in datasets:
    dataset_name = os.path.basename(dataset_path).replace('.csv','')
    print(f"📈 Processando dataset: {dataset_name}")

    df = pd.read_csv(dataset_path)
    # Select a numerical column for scaling, for example, 'ALLSKY_SFC_SW_DWN'
    values = df['ALLSKY_SFC_SW_DWN'].values.reshape(-1, 1)

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled = scaler.fit_transform(values)

    X, y = create_sequences(scaled, look_back)

    X_model = X.reshape((X.shape[0], X.shape[1], 1)) if 'MLP' in ['LSTM', 'GRU'] else X.reshape((X.shape[0], X.shape[1]))

    input_shape = (X.shape[1], 1) if 'MLP' in ['LSTM', 'GRU'] else (X.shape[1],)
    model = build_model(input_shape)

    history = model.fit(
        X_model,
        y,
        epochs=50,
        batch_size=16,
        verbose=0
    )

    y_pred = model.predict(X_model)

    y_true_inv = scaler.inverse_transform(y)
    y_pred_inv = scaler.inverse_transform(y_pred)

    metrics = evaluate_model(y_true_inv, y_pred_inv)
    metrics['Dataset'] = dataset_name
    metrics['Model'] = 'MLP'
    results.append(metrics)

    plt.figure(figsize=(10,5))
    plt.plot(y_true_inv, label='Real')
    plt.plot(y_pred_inv, label='Previsto')
    plt.title(f'Previsão - {dataset_name} - MLP')
    plt.legend()
    plot_file = outputs_path + f'plot_{dataset_name}_MLP.png'
    plt.savefig(plot_file)
    plt.show()

    df_out = pd.DataFrame({
        'Real': y_true_inv.flatten(),
        'Previsto': y_pred_inv.flatten()
    })
    output_name = outputs_path + f'resultado_{dataset_name}_MLP.csv'
    df_out.to_csv(output_name, index=False)
    print(f"✅ Resultado salvo: {output_name}")
    print(f"🖼️ Gráfico salvo: {plot_file}")

df_results = pd.DataFrame(results)
print(df_results)
df_results.to_csv(outputs_path + 'Resultados_Consolidados_MLP.csv', index=False)
print("📄 Resultados consolidados salvos em 'Resultados_Consolidados_MLP.csv'")
# Out:
# 🗂️ Bases encontradas: ['/content/drive/MyDrive/USP-IC-SIN5006/datasets/cod.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/coa.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/par.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/bar.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/bjc.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/mna.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/eir.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/mnc.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/sgc.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/lab.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/iau.csv', '/content/drive/MyDrive/USP-IC-SIN5006/datasets/tef.csv']
# 📈 Processando dataset: cod
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_cod_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_cod_MLP.png
# 📈 Processando dataset: coa
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_coa_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_coa_MLP.png
# 📈 Processando dataset: par
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_par_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_par_MLP.png
# 📈 Processando dataset: bar
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_bar_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_bar_MLP.png
# 📈 Processando dataset: bjc
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_bjc_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_bjc_MLP.png
# 📈 Processando dataset: mna
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_mna_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_mna_MLP.png
# 📈 Processando dataset: eir
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_eir_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_eir_MLP.png
# 📈 Processando dataset: mnc
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_mnc_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_mnc_MLP.png
# 📈 Processando dataset: sgc
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_sgc_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_sgc_MLP.png
# 📈 Processando dataset: lab
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_lab_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_lab_MLP.png
# 📈 Processando dataset: iau
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_iau_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_iau_MLP.png
# 📈 Processando dataset: tef
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ✅ Resultado salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/resultado_tef_MLP.csv
# 🖼️ Gráfico salvo: /content/drive/MyDrive/USP-IC-SIN5006/outputs/plot_tef_MLP.png
#          MAE      RMSE        R2 Dataset Model
# 0   0.806775  1.003490  0.205654     cod   MLP
# 1   0.791626  0.998117  0.160107     coa   MLP
# 2   0.741587  0.946277  0.334913     par   MLP
# 3   0.738387  0.953386  0.312178     bar   MLP
# 4   0.830840  1.032361  0.123792     bjc   MLP
# 5   0.910057  1.101516  0.155900     mna   MLP
# 6   0.782496  1.007241  0.154208     eir   MLP
# 7   0.757540  0.995734  0.140939     mnc   MLP
# 8   0.851007  1.069713  0.116319     sgc   MLP
# 9   0.753702  0.967723  0.186584     lab   MLP
# 10  0.857271  1.074800  0.117630     iau   MLP
# 11  0.801120  1.036125  0.145115     tef   MLP
# 📄 Resultados consolidados salvos em 'Resultados_Consolidados_MLP.csv'
